# %% [markdown]
# <a href="https://colab.research.google.com/github/edterrell/-Users-edwardterrell-Desktop-xeco_gas_billing_data_Service-1_2009-12-03_to_2019-01-03.csv/blob/master/Collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import collections
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
c = collections.Counter('hello world')

# %%
c
print()
c
# Out:
# Counter({' ': 1, 'd': 1, 'e': 1, 'h': 1, 'l': 3, 'o': 2, 'r': 1, 'w': 1})
# Counter({' ': 1, 'd': 1, 'e': 1, 'h': 1, 'l': 3, 'o': 2, 'r': 1, 'w': 1})

# %%
c.most_common(3)
# Out:
# [('l', 3), ('o', 2), ('h', 1)]

# %%
x ={'a':1,'b':2}
y = {'b':3, 'c': 4}

# %%
z = {**x,**y}

# %%
z
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
import itertools
counts = 0
for p in itertools.permutations('ABCD'):
  counts += 1
# print (p)
print (counts)
# Out:
# 24

# %%
import numpy as np
a = np.random.rand(2,3)
a
# Out:
# array([[0.08503331, 0.72506021, 0.2059016 ],
#        [0.31956884, 0.64928968, 0.232978  ]])

# %%
a*2
# Out:
# array([[0.17006661, 1.45012043, 0.41180319],
#        [0.63913768, 1.29857935, 0.46595599]])

# %%
x = 1
y = 4
x/y
# Out:
# 0.25

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,3))
ax.bar(x=['A','B','C'], height=[3.1,7,4.2], color='r')
ax.plot(['A','B','C'], [4,6,3], color='b')
ax.set_xlabel(xlabel='X title', size=20)
ax.set_ylabel(ylabel='Y title' , color='b', size=20)
plt.show()
# Out:
# <BarContainer object of 3 artists>
# Text(0.5, 0, 'X title')
# Text(0, 0.5, 'Y title')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(['Alice','Bob','Catherine'], [4,6,3], color='r')
ax.set_xlabel('TITLE 1')
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
plt.show()
# Out:
# Text(0.5, 0, 'TITLE 1')

# %%
import seaborn as sns
sns.set()
tips = sns.load_dataset("tips")
import pandas as pd
display (tips.head())
plt.rcParams['figure.figsize']=(10,10)
sns.scatterplot(x="total_bill", y="tip", data=tips, hue ='smoker',s =100)
plt.show()
tips.shape
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# (244, 7)

# %%
sns.kdeplot(tips['size'],shade=True)

# %%
tips.hist('size')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f30ea192160>]],
#       dtype=object)

# %%
tips.plot(x ='total_bill', y ='tip',kind = 'scatter',s=100)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
with sns.axes_style('white'):
    sns.jointplot("total_bill", "tip", tips, kind='kde');

# %%
import pandas as pd

df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

# %%
df
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2
# 5   lisa   33      F       texas             1         2
# 6   jose   20      M       texas             4         3

# %%
df.plot(kind='scatter',x='num_children',y='num_pets',color='red')

# %%
df.plot(kind='bar',x='name',y='age')

# %%
# gca stands for 'get current axis'
ax = plt.gca()

df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)

plt.show()

# %%
plt.savefig('output.png')

# %%
df.groupby('state')['name'].nunique().plot(kind='bar')

# %%
df.groupby(['state','gender'])['name'].size().unstack().plot(kind='bar',stacked=True)

# %%
df.head()
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2

# %%
df.groupby(['state','gender']).size()
# Out:
# state       gender
# california  M         3
# dc          F         1
#             M         1
# texas       F         1
#             M         1
# dtype: int64

# %%
df.groupby(['state','gender']).size().unstack()
# Out:
# gender        F    M
# state
# california  NaN  3.0
# dc          1.0  1.0
# texas       1.0  1.0

# %%
df.groupby(['state','gender']).size().unstack().plot(kind='bar',stacked=True)

# %%
 df.groupby(['gender','state'])['age'].size().unstack().plot(kind='bar',stacked=True,figsize =(12,5))

# %%
df.groupby(['gender','state'])['age'].size().unstack().plot(kind='bar',stacked=True)

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

df.groupby(['gender','state']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
df[['age']].plot(kind='hist',bins=[0,20,40,60,80,100],rwidth=0.8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-e70ec6a22733> in <module>()
#       1
# ----> 2 df[['age']].plot(kind='hist',bins=[0,20,40,60,80,100],rwidth=0.8)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'name':[
        'john','lisa','peter','carl','linda','betty'
    ],
    'date_of_birth':[
        '01/21/1988','03/10/1977','07/25/1999','01/22/1977','09/30/1968','09/15/1970'
    ]
})

# %%
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'],infer_datetime_format=True)

plt.clf()
df['date_of_birth'].map(lambda d: d.month).plot(kind='hist')

# %%
sns.set(style="white", rc={"lines.linewidth": 3})
fig, ax1 = plt.subplots(figsize=(4,4))
ax2 = ax1.twinx()
sns.barplot(x=['A','B','C','D'],
            y=[100,200,135,98], 
            color='#004488',
            ax=ax1)
sns.lineplot(x=['A','B','C','D'], 
             y=[4,2,5,3],
             color='r',
             marker="o",
             ax=ax2)
plt.show()
sns.set()
